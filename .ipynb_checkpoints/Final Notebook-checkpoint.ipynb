# %%
from Factors import Affordability, InventoryAnalysis, MigrationAnalysis, ZipCodeAnalysis, ZipcodeCleanup

# %%
Affordability.main()

# %%
InventoryAnalysis.main()

# %%
MigrationAnalysis.main()

# %%
ZipCodeAnalysis.main()

# %%
ZipcodeCleanup.main()
